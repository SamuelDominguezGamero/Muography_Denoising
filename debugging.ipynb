# %%
import ROOT
import numpy as np
import matplotlib.pyplot as plt

# %%
# !ls *.root
# Out:
# dataset_correlacionado_fixed.root	 poca_points.root
# dataset_correlacionado_fixed_QUICK.root	 prueba_04mayo.root

# %%
f = ROOT.TFile.Open("dataset_correlacionado_fixed.root")
f.ls()

df_hits = ROOT.RDataFrame("events", f)
# Out:
# TFile**		dataset_correlacionado_fixed.root
#  TFile*		dataset_correlacionado_fixed.root
#   KEY: TTree	events;2	events [current cycle]
#   KEY: TTree	events;1	events [backup cycle]

# %%
df_hits.Display()
# Out:
# <cppyy.gbl.ROOT.RDF.RResultPtr<ROOT::RDF::RDisplay> object at 0x644dafe30c60>

# %%
g = df_PocaPoints = ROOT.RDataFrame("poca_points.root")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 g = df_PocaPoints = ROOT.RDataFrame("poca_points.root")
#
# File ~/miniforge3/envs/Master_env/lib/python3.12/site-packages/ROOT/_pythonization/_rdf_namespace.py:103, in _rdataframe.<locals>.rdataframe(*args, **kwargs)
#     101     rnode = ROOT.RDF.AsRNode(rdf._headnode.rdf_node)
#     102 else:
# --> 103     rdf = local_rdf(*args, **kwargs)
#     104     rnode = ROOT.RDF.AsRNode(rdf)
#     106 if args and isinstance(args[0], ROOT.TTree):
#
# TypeError: none of the 10 overloaded methods succeeded. Full details:
#   RDataFrame::RDataFrame(string_view treename, initializer_list<string> filenames, const ROOT::RDataFrame::ColumnNames_t& defaultColumns = {}) =>
#     TypeError: takes at least 2 arguments (1 given)
#   RDataFrame::RDataFrame(ROOT::RDataFrame&&) =>
#     TypeError: could not convert argument 1
#   RDataFrame::RDataFrame(string_view treeName, TDirectory* dirPtr, const ROOT::RDataFrame::ColumnNames_t& defaultColumns = {}) =>
#     TypeError: takes at least 2 arguments (1 given)
#   RDataFrame::RDataFrame(TTree& tree, const ROOT::RDataFrame::ColumnNames_t& defaultColumns = {}) =>
#     TypeError: could not convert argument 1
#   RDataFrame::RDataFrame(const ROOT::RDataFrame&) =>
#     TypeError: could not convert argument 1
#   RDataFrame::RDataFrame(string_view treename, const vector<string>& filenames, const ROOT::RDataFrame::ColumnNames_t& defaultColumns = {}) =>
#     TypeError: takes at least 2 arguments (1 given)
#   RDataFrame::RDataFrame(string_view treeName, string_view filenameglob, const ROOT::RDataFrame::ColumnNames_t& defaultColumns = {}) =>
#     TypeError: takes at least 2 arguments (1 given)
#   an integer is required
#   RDataFrame::RDataFrame(unique_ptr<ROOT::RDF::RDataSource>, const ROOT::RDataFrame::ColumnNames_t& defaultColumns = {}) =>
#     TypeError: could not convert argument 1
#   RDataFrame::RDataFrame(ROOT::RDF::Experimental::RDatasetSpec spec) =>
#     TypeError: could not convert argument 1
